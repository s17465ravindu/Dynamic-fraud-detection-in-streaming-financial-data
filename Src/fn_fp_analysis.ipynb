# %%
from numpy import loadtxt
from keras.models import load_model
from sklearn.metrics import confusion_matrix
from lime.lime_tabular import LimeTabularExplainer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %%
df_lstm = pd.read_csv(r'D:\Uni Docs\DSC4996\Dynamic_fraud_detection_system\Data\Dataset03.csv')

# %%
df_lstm = df_lstm.drop('Unnamed: 0', axis=1)

# %%
df_lstm.shape
# Out:
# (284910, 31)

# %%
X = df_lstm.drop(['Class'], axis = 'columns')
Label_Data = df_lstm['Class']

# %%
X_r2 = StandardScaler().fit_transform(X)

# %%
X_train,X_test,y_train,y_test = train_test_split(X_r2, Label_Data, test_size=0.3)

# %%
X_val, X_test1, y_val, y_test1 = train_test_split(X_test, y_test, test_size=0.5, random_state=42)

# %%
# design network
np.random.seed(7)

train_LSTM_X=X_train
val_LSTM_X=X_val

## Reshape input to be 3D [samples, timesteps, features] (format requis par LSTM)
train_LSTM_X = train_LSTM_X.reshape((train_LSTM_X.shape[0], 1, train_LSTM_X.shape[1]))
val_LSTM_X = val_LSTM_X.reshape((val_LSTM_X.shape[0], 1, val_LSTM_X.shape[1]))

train_LSTM_y=y_train
val_LSTM_y=y_val

test_LSTM_X = X_test1.reshape((X_test1.shape[0], 1, X_test1.shape[1]))

# %%
model = load_model(r'D:\Uni Docs\DSC4996\Dynamic_fraud_detection_system\LSTM\lstm_Model_gan_with_es.h5')

# %%
# predict probabilities for test set
yhat_probs = model.predict(test_LSTM_X, verbose=0)
# reduce to 1d array
yhat_probs = yhat_probs[:, 0]

# %%
yhat_classes = (yhat_probs > 0.5).astype(int)

# %%
cm_lstm = confusion_matrix(y_test1, yhat_classes)

# %%
cm_lstm
# Out:
# array([[29893,    11],
#        [   17, 12816]], dtype=int64)

# %%
TN, FP, FN, TP = cm_lstm.ravel()

# %%
# Convert the Series to numpy arrays
y_test1_array = y_test1.values

# %%
# Get the indices of FP and FN instances
FP_indices = [i for i in range(len(y_test1_array)) if y_test1_array[i]==0 and yhat_classes[i]==1]
FN_indices = [i for i in range(len(y_test1_array)) if y_test1_array[i]==1 and yhat_classes[i]==0]

# %%
def predict_proba(data, model):
    # Reshape data for LSTM
    data_reshaped = data.reshape(-1, 1, 30)
    proba = model.predict(data_reshaped)
    return np.hstack((1 - proba, proba))

# %%
explainer = LimeTabularExplainer(train_LSTM_X.reshape(-1, train_LSTM_X.shape[2]), 
                                 feature_names=X.columns, 
                                 class_names=['Genuine', 'Fraud'], 
                                 verbose=True, 
                                 mode='classification')

# %%
test_LSTM_X.shape
# Out:
# (42737, 1, 30)

# %%
FP_explanations = []
for i in FP_indices:
    exp = explainer.explain_instance(test_LSTM_X[i].reshape(-1), 
                                     lambda x: predict_proba(x.reshape(-1, 1, 30), model),  # change this line
                                     num_features=5)
    FP_explanations.append(exp)
# Out:
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0045569395878472625
# Prediction_local [0.03221367]
# Right: 0.88083994
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.007167063180634538
# Prediction_local [0.0449061]
# Right: 0.81007934
# 157/157 [==============================] - 0s 891us/step
# Intercept -0.005492763771930336
# Prediction_local [0.03307488]
# Right: 0.8663007
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.003826163508928569
# Prediction_local [0.02919273]
# Right: 0.8969698
# 157/157 [==============================] - 0s 929us/step
# Intercept -0.004776385516475357
# Prediction_local [0.03595193]
# Right: 0.81148285
# 157/157 [==============================] - 0s 932us/step
# Intercept -0.0036042528400174493
# Prediction_local [0.02794299]
# Right: 0.77302366
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.006485123041376651
# Prediction_local [0.03911175]
# Right: 0.8804319
# 157/157 [==============================] - 0s 942us/step
# Intercept -0.00502477212040824
# Prediction_local [0.03336452]
# Right: 0.8111771
# 157/157 [==============================] - 0s 927us/step
# Intercept -0.004887402175378981
# Prediction_local [0.03253867]
# Right: 0.8238771
# 157/157 [==============================] - 0s 936us/step
# Intercept -0.003024272145031614
# Prediction_local [0.02718903]
# Right: 0.80185777
# 157/157 [==============================] - 0s 896us/step
# Intercept -0.0044988927024948045
# Prediction_local [0.03349013]
# Right: 0.7738451

# %%
FN_explanations = []
for i in FN_indices:
    exp = explainer.explain_instance(test_LSTM_X[i].reshape(-1), 
                                     lambda x: predict_proba(x.reshape(-1, 1, 30), model), 
                                     num_features=5)
    FN_explanations.append(exp)
# Out:
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0023681396311234755
# Prediction_local [0.02488844]
# Right: 0.119267754
# 157/157 [==============================] - 0s 953us/step
# Intercept 0.0052595700307148385
# Prediction_local [0.00193985]
# Right: 0.0023365393
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0007885738989767428
# Prediction_local [0.02463849]
# Right: 1.3565402e-05
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.005917766447199621
# Prediction_local [0.00640813]
# Right: 1.750426e-05
# 157/157 [==============================] - 0s 964us/step
# Intercept -0.004664264660673033
# Prediction_local [0.03041305]
# Right: 0.20574531
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.0020245763591793427
# Prediction_local [0.00933411]
# Right: 0.00020953258
# 157/157 [==============================] - 0s 975us/step
# Intercept -0.0034292256668449032
# Prediction_local [0.03134237]
# Right: 0.17813475
# 157/157 [==============================] - 0s 965us/step
# Intercept 0.000518120041661325
# Prediction_local [0.02226116]
# Right: 0.075207174
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.005895144112469423
# Prediction_local [0.0361075]
# Right: 0.029389292
# 157/157 [==============================] - 0s 915us/step
# Intercept 0.0020045771065393915
# Prediction_local [0.01408146]
# Right: 0.00041585873
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.0022989176821811355
# Prediction_local [0.01351265]
# Right: 0.0009771427
# 157/157 [==============================] - 0s 921us/step
# Intercept 0.0018744668225387658
# Prediction_local [0.01394741]
# Right: 0.0005972565
# 157/157 [==============================] - 0s 976us/step
# Intercept -0.002964759029449881
# Prediction_local [0.03060155]
# Right: 0.07612043
# 157/157 [==============================] - 0s 983us/step
# Intercept 0.012314851578047263
# Prediction_local [-0.01410957]
# Right: 6.7448345e-05
# 157/157 [==============================] - 0s 965us/step
# Intercept 0.0019222892215684673
# Prediction_local [0.01461892]
# Right: 0.009325709
# 157/157 [==============================] - 0s 919us/step
# Intercept -0.0017044434954695499
# Prediction_local [0.02466699]
# Right: 0.21668582
# 157/157 [==============================] - 0s 991us/step
# Intercept 0.0038055705239412613
# Prediction_local [0.00700099]
# Right: 1.4294062e-06

# %%
FP_feature_importances = np.zeros(len(X.columns))
FN_feature_importances = np.zeros(len(X.columns))

# %%
feature_name_to_index = {name: index for index, name in enumerate(X.columns)}

# %%
for exp in FP_explanations:
    for feature_name, importance in exp.as_list():
        original_feature_name = feature_name.split(' ')[0]
        if original_feature_name in feature_name_to_index:
            feature_index = feature_name_to_index[original_feature_name]
            FP_feature_importances[feature_index] += np.abs(importance)

# %%
for exp in FN_explanations:
    for feature_name, importance in exp.as_list():
        original_feature_name = feature_name.split(' ')[0]
        if original_feature_name in feature_name_to_index:
            feature_index = feature_name_to_index[original_feature_name]
            FN_feature_importances[feature_index] += np.abs(importance)

# %%
FP_feature_importances /= np.sum(FP_feature_importances)
FN_feature_importances /= np.sum(FN_feature_importances)

# %% [markdown]
# ### Flase positive

# %%
for feature_name, fp_importance in zip(X.columns, FP_feature_importances):
    print(f"{feature_name}:{fp_importance}")
# Out:
# Time:0.0
# V1:0.0
# V2:0.029211479660968275
# V3:0.06848481565206174
# V4:0.1423810830722951
# V5:0.0
# V6:0.0
# V7:0.14319009527182192
# V8:0.0
# V9:0.02652916050451221
# V10:0.06111919068387853
# V11:0.029221451056743033
# V12:0.24998364600294748
# V13:0.0
# V14:0.1630565167802727
# V15:0.0
# V16:0.05649008742384575
# V17:0.030332473890653116
# V18:0.0
# V19:0.0
# V20:0.0
# V21:0.0
# V22:0.0
# V23:0.0
# V24:0.0
# V25:0.0
# V26:0.0
# V27:0.0
# V28:0.0
# Amount:0.0

# %% [markdown]
# ### False Negetive

# %%
for feature_name, fn_importance in zip(X.columns, FN_feature_importances):
    print(f"{feature_name}:{fn_importance}")
# Out:
# Time:0.0
# V1:0.012364153954567208
# V2:0.06921226575903483
# V3:0.031173738965857126
# V4:0.15948416725044692
# V5:0.0
# V6:0.0061312434076639276
# V7:0.13532407299909352
# V8:0.021951046565225372
# V9:0.04312936816125782
# V10:0.03548262076907327
# V11:0.030912260146140135
# V12:0.25941482351604483
# V13:0.0
# V14:0.119931645073924
# V15:0.0
# V16:0.036818708430059924
# V17:0.014435520657692841
# V18:0.0
# V19:0.0
# V20:0.0069334844821457116
# V21:0.0
# V22:0.009762798031784564
# V23:0.0
# V24:0.0
# V25:0.0
# V26:0.0
# V27:0.0
# V28:0.0075380818299881115
# Amount:0.0

# %% [markdown]
# ### Correct Predictions

# %%
TP_indices = [i for i in range(len(y_test1_array)) if y_test1_array[i]==1 and yhat_classes[i]==1]
TN_indices = [i for i in range(len(y_test1_array)) if y_test1_array[i]==0 and yhat_classes[i]==0]

# %%
True_predictions_indices = TP_indices + TN_indices

# %%
len(True_predictions_indices)
# Out:
# 42709

# %%
N = 1000
True_predictions_explanations = []
for i in range(N):
    exp = explainer.explain_instance(test_LSTM_X[i].reshape(-1), 
                                     lambda x: predict_proba(x.reshape(-1, 1, 30), model), 
                                     num_features=5)
    True_predictions_explanations.append(exp)
# Out:
# 157/157 [==============================] - 0s 918us/step
# Intercept 0.006160781799326106
# Prediction_local [-0.00407159]
# Right: 8.917685e-06
# 157/157 [==============================] - 0s 958us/step
# Intercept -0.001671471338490279
# Prediction_local [0.02731981]
# Right: 0.9999967
# 157/157 [==============================] - 0s 964us/step
# Intercept -0.0005966253736280356
# Prediction_local [0.02187562]
# Right: 0.9999963
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001959113859053936
# Prediction_local [0.01132568]
# Right: 2.9014076e-05
# 157/157 [==============================] - 0s 892us/step
# Intercept -0.0007054297388660435
# Prediction_local [0.01900828]
# Right: 0.9999949
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0030924545843034456
# Prediction_local [0.00995878]
# Right: 0.00010557292
# 157/157 [==============================] - 0s 993us/step
# Intercept 0.00473810971564268
# Prediction_local [0.00308081]
# Right: 3.28879e-06
# 157/157 [==============================] - 0s 904us/step
# Intercept 1.1048521274844084e-05
# Prediction_local [0.01970253]
# Right: 0.9999958
# 157/157 [==============================] - 0s 917us/step
# Intercept 0.0035811085511953562
# Prediction_local [0.0122536]
# Right: 7.552032e-07
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.0011037343639209883
# Prediction_local [0.01389223]
# Right: 4.4960775e-06
# 157/157 [==============================] - 0s 906us/step
# Intercept -0.00035001249457922504
# Prediction_local [0.01795816]
# Right: 4.390428e-05
# 157/157 [==============================] - 0s 909us/step
# Intercept 0.00834148492532921
# Prediction_local [-0.00389235]
# Right: 3.2651174e-06
# 157/157 [==============================] - 0s 941us/step
# Intercept -0.001425093590204294
# Prediction_local [0.02073211]
# Right: 5.1745064e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005928054077728014
# Prediction_local [0.00070847]
# Right: 8.661249e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004995127176679192
# Prediction_local [0.00276435]
# Right: 0.0001928094
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.006074626541050437
# Prediction_local [0.00405639]
# Right: 3.868523e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0010758179979942716
# Prediction_local [0.01821099]
# Right: 1.2170023e-05
# 157/157 [==============================] - 0s 914us/step
# Intercept 0.0003987350226924225
# Prediction_local [0.01750443]
# Right: 3.7048355e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.000558405276015317
# Prediction_local [0.02343452]
# Right: 0.99999607
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005201591368660036
# Prediction_local [0.00391687]
# Right: 4.735394e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004694710026298573
# Prediction_local [0.00719897]
# Right: 1.4483633e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00395381581051862
# Prediction_local [0.005081]
# Right: 1.0385655e-05
# 157/157 [==============================] - 0s 889us/step
# Intercept -0.0022118086285194266
# Prediction_local [0.02642254]
# Right: 0.99999636
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0020230713992402992
# Prediction_local [0.01221928]
# Right: 1.7080189e-05
# 157/157 [==============================] - 0s 939us/step
# Intercept -0.00349204651614282
# Prediction_local [0.03513054]
# Right: 0.999995
# 157/157 [==============================] - 0s 887us/step
# Intercept -0.0010593801385054766
# Prediction_local [0.02427256]
# Right: 0.99999607
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.004581982317196833
# Prediction_local [0.00400099]
# Right: 1.0657878e-05
# 157/157 [==============================] - 0s 922us/step
# Intercept -0.00022135499839437585
# Prediction_local [0.02522261]
# Right: 1.1488912e-06
# 157/157 [==============================] - 0s 885us/step
# Intercept 0.002817942524195185
# Prediction_local [0.00939453]
# Right: 2.3197617e-06
# 157/157 [==============================] - 0s 956us/step
# Intercept 0.005963683731602938
# Prediction_local [0.0015062]
# Right: 2.489493e-06
# 157/157 [==============================] - 0s 974us/step
# Intercept 0.00438532816107129
# Prediction_local [0.00658683]
# Right: 4.467221e-05
# 157/157 [==============================] - 0s 932us/step
# Intercept -0.00029109711468433986
# Prediction_local [0.01942855]
# Right: 0.99999535
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0005875615545993347
# Prediction_local [0.02308841]
# Right: 2.1805972e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0028176635664239552
# Prediction_local [0.0099541]
# Right: 5.2909145e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.0017419801157683842
# Prediction_local [0.01287473]
# Right: 1.5909864e-05
# 157/157 [==============================] - 0s 959us/step
# Intercept 0.005137833658499439
# Prediction_local [0.00236122]
# Right: 2.519215e-05
# 157/157 [==============================] - 0s 926us/step
# Intercept -0.0015451170343476484
# Prediction_local [0.01951305]
# Right: 2.312402e-06
# 157/157 [==============================] - 0s 905us/step
# Intercept -0.00274875344249147
# Prediction_local [0.02537986]
# Right: 0.99999607
# 157/157 [==============================] - 0s 930us/step
# Intercept -0.0027103945275261986
# Prediction_local [0.02951749]
# Right: 0.99999577
# 157/157 [==============================] - 0s 884us/step
# Intercept 0.0020678562579871775
# Prediction_local [0.01300429]
# Right: 9.300449e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004461525592424333
# Prediction_local [0.0016214]
# Right: 1.7682543e-05
# 157/157 [==============================] - 0s 911us/step
# Intercept 0.007409368494574622
# Prediction_local [-0.0050062]
# Right: 9.723134e-06
# 157/157 [==============================] - 0s 910us/step
# Intercept -0.0012898764611881715
# Prediction_local [0.02184575]
# Right: 0.99999624
# 157/157 [==============================] - 0s 902us/step
# Intercept -0.0024111297920415865
# Prediction_local [0.02750447]
# Right: 0.9999956
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002357253190031365
# Prediction_local [0.01152932]
# Right: 6.2698937e-06
# 157/157 [==============================] - 0s 922us/step
# Intercept 0.0064601470116144016
# Prediction_local [0.00348016]
# Right: 1.0869563e-06
# 157/157 [==============================] - 0s 901us/step
# Intercept 0.003931197189556248
# Prediction_local [0.00773073]
# Right: 1.0961807e-05
# 157/157 [==============================] - 0s 908us/step
# Intercept 0.0018811734447769946
# Prediction_local [0.01252498]
# Right: 1.599757e-06
# 157/157 [==============================] - 0s 872us/step
# Intercept -0.002207167333840095
# Prediction_local [0.03186243]
# Right: 0.99999654
# 157/157 [==============================] - 0s 888us/step
# Intercept 0.005776440101853844
# Prediction_local [0.005626]
# Right: 1.8680372e-06
# 157/157 [==============================] - 0s 886us/step
# Intercept -0.0009631161308503644
# Prediction_local [0.02563077]
# Right: 0.9999966
# 157/157 [==============================] - 0s 942us/step
# Intercept 0.0038274498004921094
# Prediction_local [0.00692408]
# Right: 1.7249182e-05
# 157/157 [==============================] - 0s 926us/step
# Intercept -0.0008302274296009497
# Prediction_local [0.01990765]
# Right: 1.1329621e-05
# 157/157 [==============================] - 0s 922us/step
# Intercept -0.00016289151136543358
# Prediction_local [0.02393081]
# Right: 1.2298198e-05
# 157/157 [==============================] - 0s 905us/step
# Intercept -0.001210481115370689
# Prediction_local [0.01904074]
# Right: 6.8012882e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0011417320602156132
# Prediction_local [0.02245694]
# Right: 0.99999607
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001799785183918469
# Prediction_local [0.02687662]
# Right: 0.9999957
# 157/157 [==============================] - 0s 888us/step
# Intercept -0.001627063116028709
# Prediction_local [0.02568958]
# Right: 0.9999966
# 157/157 [==============================] - 0s 986us/step
# Intercept 0.002143124579584229
# Prediction_local [0.01005505]
# Right: 2.8432194e-06
# 157/157 [==============================] - 0s 975us/step
# Intercept 0.0005103423818170376
# Prediction_local [0.01633601]
# Right: 7.897415e-06
# 157/157 [==============================] - 0s 989us/step
# Intercept 0.0024032010865158407
# Prediction_local [0.01198933]
# Right: 5.3972494e-06
# 157/157 [==============================] - 0s 930us/step
# Intercept 0.0028365017834358743
# Prediction_local [0.01146515]
# Right: 5.388316e-06
# 157/157 [==============================] - 0s 977us/step
# Intercept -0.0005965340544120444
# Prediction_local [0.01969471]
# Right: 0.000172151
# 157/157 [==============================] - 0s 886us/step
# Intercept -0.00023346800108412554
# Prediction_local [0.02458966]
# Right: 0.99999577
# 157/157 [==============================] - 0s 958us/step
# Intercept 0.0069191609604932255
# Prediction_local [-0.00045847]
# Right: 4.1330763e-06
# 157/157 [==============================] - 0s 993us/step
# Intercept 0.005064595447712657
# Prediction_local [0.00380819]
# Right: 9.515693e-07
# 157/157 [==============================] - 0s 919us/step
# Intercept 0.0003012606088316659
# Prediction_local [0.0146479]
# Right: 4.145883e-06
# 157/157 [==============================] - 0s 939us/step
# Intercept -0.0022007523040581687
# Prediction_local [0.03271406]
# Right: 0.9999966
# 157/157 [==============================] - 0s 920us/step
# Intercept 0.005331968957598994
# Prediction_local [0.00270044]
# Right: 3.8591193e-06
# 157/157 [==============================] - 0s 975us/step
# Intercept 0.010252992795704066
# Prediction_local [-0.0078518]
# Right: 3.2397388e-06
# 157/157 [==============================] - 0s 920us/step
# Intercept -0.002018116520201267
# Prediction_local [0.02512411]
# Right: 0.9999957
# 157/157 [==============================] - 0s 930us/step
# Intercept 0.005405054210451226
# Prediction_local [0.00519601]
# Right: 2.4838466e-06
# 157/157 [==============================] - 0s 885us/step
# Intercept -0.004103061401537082
# Prediction_local [0.0360422]
# Right: 8.026003e-05
# 157/157 [==============================] - 0s 883us/step
# Intercept 0.002406203876809106
# Prediction_local [0.01060902]
# Right: 2.30093e-06
# 157/157 [==============================] - 0s 921us/step
# Intercept 9.664057351723831e-05
# Prediction_local [0.02004081]
# Right: 0.9999969
# 157/157 [==============================] - 0s 959us/step
# Intercept 0.0022315929865159337
# Prediction_local [0.008215]
# Right: 9.541374e-07
# 157/157 [==============================] - 0s 882us/step
# Intercept -0.001631305917285138
# Prediction_local [0.02249898]
# Right: 0.9999955
# 157/157 [==============================] - 0s 925us/step
# Intercept 0.0034376559174005717
# Prediction_local [0.00903392]
# Right: 7.098715e-07
# 157/157 [==============================] - 0s 959us/step
# Intercept 0.0019242834206070827
# Prediction_local [0.01252439]
# Right: 4.6419223e-06
# 157/157 [==============================] - 0s 880us/step
# Intercept 0.0016378766455196281
# Prediction_local [0.01998652]
# Right: 0.9999958
# 157/157 [==============================] - 0s 876us/step
# Intercept 0.006163613587061562
# Prediction_local [0.00377271]
# Right: 5.854474e-05
# 157/157 [==============================] - 0s 907us/step
# Intercept 0.0033778206463051354
# Prediction_local [0.01024305]
# Right: 8.729105e-06
# 157/157 [==============================] - 0s 895us/step
# Intercept 0.00044295441056432447
# Prediction_local [0.02167759]
# Right: 6.791903e-06
# 157/157 [==============================] - 0s 910us/step
# Intercept 0.003481366015512708
# Prediction_local [0.00353063]
# Right: 7.277741e-06
# 157/157 [==============================] - 0s 958us/step
# Intercept 0.001184783298777592
# Prediction_local [0.01682531]
# Right: 5.5251826e-06
# 157/157 [==============================] - 0s 878us/step
# Intercept 0.002156296631869942
# Prediction_local [0.008683]
# Right: 0.0004108376
# 157/157 [==============================] - 0s 919us/step
# Intercept -0.0028947155300938637
# Prediction_local [0.02890477]
# Right: 0.9999936
# 157/157 [==============================] - 0s 991us/step
# Intercept -0.00036232870681125306
# Prediction_local [0.01730645]
# Right: 2.743008e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00247521169167843
# Prediction_local [0.00857636]
# Right: 1.3665726e-06
# 157/157 [==============================] - 0s 940us/step
# Intercept 0.005069125124426844
# Prediction_local [0.00383119]
# Right: 1.8032937e-06
# 157/157 [==============================] - 0s 845us/step
# Intercept -0.0007173069708374669
# Prediction_local [0.01783338]
# Right: 0.99999624
# 157/157 [==============================] - 0s 893us/step
# Intercept 0.0033605067610908697
# Prediction_local [0.00969708]
# Right: 3.578017e-05
# 157/157 [==============================] - 0s 880us/step
# Intercept 0.0027038813694827257
# Prediction_local [0.01355172]
# Right: 1.7348246e-05
# 157/157 [==============================] - 0s 899us/step
# Intercept 0.001978677909125732
# Prediction_local [0.01484716]
# Right: 9.129508e-06
# 157/157 [==============================] - 0s 926us/step
# Intercept 0.00017168085814024767
# Prediction_local [0.01678186]
# Right: 7.3681217e-06
# 157/157 [==============================] - 0s 899us/step
# Intercept 0.001820261653620832
# Prediction_local [0.01079793]
# Right: 2.133477e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0014133152043818943
# Prediction_local [0.02157311]
# Right: 0.9999966
# 157/157 [==============================] - 0s 919us/step
# Intercept 0.0004570296548798867
# Prediction_local [0.02289519]
# Right: 0.9999958
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.00026142317114052037
# Prediction_local [0.02302667]
# Right: 0.99999624
# 157/157 [==============================] - 0s 958us/step
# Intercept 0.005711172617249495
# Prediction_local [-0.00018902]
# Right: 1.7317661e-06
# 157/157 [==============================] - 0s 983us/step
# Intercept -0.001131245057525549
# Prediction_local [0.02359921]
# Right: 0.99999577
# 157/157 [==============================] - 0s 960us/step
# Intercept 0.0012213434545631733
# Prediction_local [0.01293117]
# Right: 1.2544068e-05
# 157/157 [==============================] - 0s 984us/step
# Intercept 0.0036214822744521083
# Prediction_local [0.00750439]
# Right: 1.3357999e-06
# 157/157 [==============================] - 0s 888us/step
# Intercept -0.00032362603010220245
# Prediction_local [0.01955139]
# Right: 5.1337925e-06
# 157/157 [==============================] - 0s 917us/step
# Intercept -0.0015650948016549728
# Prediction_local [0.02189404]
# Right: 1.2592551e-05
# 157/157 [==============================] - 0s 888us/step
# Intercept 0.012365086558112134
# Prediction_local [-0.01445951]
# Right: 1.0213959e-05
# 157/157 [==============================] - 0s 995us/step
# Intercept -0.0010305999101452813
# Prediction_local [0.02466815]
# Right: 0.9999954
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002454391809541869
# Prediction_local [0.00829374]
# Right: 4.956278e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005171492175898941
# Prediction_local [0.00531695]
# Right: 2.980376e-07
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.001122892134091764
# Prediction_local [0.01843148]
# Right: 2.7258932e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004927579503713558
# Prediction_local [0.00305675]
# Right: 3.9782e-05
# 157/157 [==============================] - 0s 992us/step
# Intercept 0.005004985114990266
# Prediction_local [0.00212405]
# Right: 3.6960086e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00012916035719190248
# Prediction_local [0.01647526]
# Right: 1.8848153e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0002874112624078832
# Prediction_local [0.02038574]
# Right: 0.99999624
# 157/157 [==============================] - 0s 995us/step
# Intercept 0.0014956982889841256
# Prediction_local [0.00366526]
# Right: 1.6978443e-05
# 157/157 [==============================] - 0s 917us/step
# Intercept -0.002253845589818829
# Prediction_local [0.02728861]
# Right: 0.9999945
# 157/157 [==============================] - 0s 997us/step
# Intercept 0.0021409638127781495
# Prediction_local [0.01015357]
# Right: 2.6517473e-06
# 157/157 [==============================] - 0s 978us/step
# Intercept -0.000340846353602999
# Prediction_local [0.02570533]
# Right: 0.9999961
# 157/157 [==============================] - 0s 882us/step
# Intercept 0.006880369482894685
# Prediction_local [0.00287877]
# Right: 7.3774635e-07
# 157/157 [==============================] - 0s 844us/step
# Intercept 0.005073321788812637
# Prediction_local [0.00873666]
# Right: 5.7160603e-05
# 157/157 [==============================] - 0s 997us/step
# Intercept 0.0027771053698804806
# Prediction_local [0.01502512]
# Right: 1.0141098e-05
# 157/157 [==============================] - 0s 923us/step
# Intercept 0.008100760558228826
# Prediction_local [-0.00532906]
# Right: 3.0428557e-06
# 157/157 [==============================] - 0s 877us/step
# Intercept 0.0061992705088486375
# Prediction_local [-0.00086027]
# Right: 6.4425797e-07
# 157/157 [==============================] - 0s 889us/step
# Intercept -0.000358116154663894
# Prediction_local [0.02358918]
# Right: 0.99999607
# 157/157 [==============================] - 0s 901us/step
# Intercept 0.004925618199034924
# Prediction_local [0.00311926]
# Right: 5.4124007e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001051431826463902
# Prediction_local [0.01813315]
# Right: 0.9999953
# 157/157 [==============================] - 0s 886us/step
# Intercept 0.002881640994871953
# Prediction_local [0.01507814]
# Right: 3.315938e-05
# 157/157 [==============================] - 0s 973us/step
# Intercept -0.0015115145682805938
# Prediction_local [0.02501758]
# Right: 0.999996
# 157/157 [==============================] - 0s 867us/step
# Intercept 0.006137850640860745
# Prediction_local [-0.00092349]
# Right: 1.0407983e-05
# 157/157 [==============================] - 0s 939us/step
# Intercept 0.003458522189182435
# Prediction_local [0.01040175]
# Right: 4.1215476e-06
# 157/157 [==============================] - 0s 894us/step
# Intercept 0.004880686003677529
# Prediction_local [0.0019889]
# Right: 2.7008344e-05
# 157/157 [==============================] - 0s 973us/step
# Intercept -0.0015606058195954528
# Prediction_local [0.02321222]
# Right: 0.99999666
# 157/157 [==============================] - 0s 942us/step
# Intercept 0.002812944431679374
# Prediction_local [0.01648667]
# Right: 7.974619e-06
# 157/157 [==============================] - 0s 970us/step
# Intercept 0.003564340789260446
# Prediction_local [0.00099995]
# Right: 3.109429e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.0023259043157612307
# Prediction_local [0.00867712]
# Right: 0.00033339285
# 157/157 [==============================] - 0s 932us/step
# Intercept -0.0003583856776544188
# Prediction_local [0.01916404]
# Right: 0.99999666
# 157/157 [==============================] - 0s 857us/step
# Intercept 0.0005913272210084433
# Prediction_local [0.01207776]
# Right: 3.795974e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002961699531069131
# Prediction_local [0.00842722]
# Right: 3.5886867e-06
# 157/157 [==============================] - 0s 983us/step
# Intercept 0.004726405234952895
# Prediction_local [0.00430561]
# Right: 4.4596136e-06
# 157/157 [==============================] - 0s 977us/step
# Intercept 0.006461438663363997
# Prediction_local [0.00109565]
# Right: 5.5552304e-05
# 157/157 [==============================] - 0s 893us/step
# Intercept -0.0009680460452297993
# Prediction_local [0.02484598]
# Right: 8.979626e-06
# 157/157 [==============================] - 0s 947us/step
# Intercept 0.007384038314352333
# Prediction_local [-0.00412599]
# Right: 2.6782684e-06
# 157/157 [==============================] - 0s 960us/step
# Intercept 0.0030042792972077076
# Prediction_local [0.00534856]
# Right: 2.140586e-05
# 157/157 [==============================] - 0s 996us/step
# Intercept -0.00011109686873305488
# Prediction_local [0.01762797]
# Right: 7.143679e-06
# 157/157 [==============================] - 0s 925us/step
# Intercept 0.0024459526225787624
# Prediction_local [0.01296429]
# Right: 2.2263787e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept -0.00010041265442975629
# Prediction_local [0.01690191]
# Right: 6.848207e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001967233914886511
# Prediction_local [0.02447644]
# Right: 0.99999654
# 157/157 [==============================] - 0s 928us/step
# Intercept 0.0025172836528887296
# Prediction_local [0.01087045]
# Right: 4.351432e-06
# 157/157 [==============================] - 0s 982us/step
# Intercept 0.0031167292108372525
# Prediction_local [0.01533538]
# Right: 3.9958004e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0019800729724166726
# Prediction_local [0.02960336]
# Right: 0.99999595
# 157/157 [==============================] - 0s 979us/step
# Intercept 0.009469781021602876
# Prediction_local [-0.00726347]
# Right: 0.00030130876
# 157/157 [==============================] - 0s 963us/step
# Intercept 0.004253127176226237
# Prediction_local [0.00078473]
# Right: 0.00019635912
# 157/157 [==============================] - 0s 980us/step
# Intercept 0.0018040151639931194
# Prediction_local [0.01351168]
# Right: 6.657088e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0061334231782854375
# Prediction_local [0.00142392]
# Right: 1.486525e-05
# 157/157 [==============================] - 0s 968us/step
# Intercept 0.0009808219383622566
# Prediction_local [0.01807673]
# Right: 1.30578865e-05
# 157/157 [==============================] - 0s 887us/step
# Intercept 0.008244084853559736
# Prediction_local [-0.00544343]
# Right: 1.2294634e-05
# 157/157 [==============================] - 0s 974us/step
# Intercept -0.0027458427547685134
# Prediction_local [0.02628988]
# Right: 0.99999666
# 157/157 [==============================] - 0s 985us/step
# Intercept -0.0010612556962569502
# Prediction_local [0.02304945]
# Right: 0.99999434
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0027926033851354524
# Prediction_local [0.00875457]
# Right: 0.00010740025
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00032170072855965907
# Prediction_local [0.01900423]
# Right: 0.9999962
# 157/157 [==============================] - 0s 966us/step
# Intercept -2.4222537969778926e-05
# Prediction_local [0.01948932]
# Right: 0.99999475
# 157/157 [==============================] - 0s 948us/step
# Intercept 0.0026056032761455255
# Prediction_local [0.01114468]
# Right: 5.3008713e-05
# 157/157 [==============================] - 0s 908us/step
# Intercept 0.00367204517428326
# Prediction_local [0.00568279]
# Right: 3.956426e-06
# 157/157 [==============================] - 0s 963us/step
# Intercept 0.0055870957113272135
# Prediction_local [0.00351906]
# Right: 2.3989355e-06
# 157/157 [==============================] - 0s 940us/step
# Intercept 3.1540733268139824e-05
# Prediction_local [0.02290959]
# Right: 8.17427e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept -0.0020646337249419387
# Prediction_local [0.02520702]
# Right: 0.99999523
# 157/157 [==============================] - 0s 947us/step
# Intercept 0.005688604949300343
# Prediction_local [-0.00356886]
# Right: 5.519363e-06
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.0020164241790102894
# Prediction_local [0.01125424]
# Right: 2.436424e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.008156942153164978
# Prediction_local [-0.00586647]
# Right: 4.9112646e-06
# 157/157 [==============================] - 0s 904us/step
# Intercept 0.005746550181006517
# Prediction_local [0.0015151]
# Right: 2.3264101e-06
# 157/157 [==============================] - 0s 885us/step
# Intercept 0.007252189665756855
# Prediction_local [-0.0017159]
# Right: 1.0595289e-05
# 157/157 [==============================] - 0s 967us/step
# Intercept 0.007348336586371123
# Prediction_local [0.00130985]
# Right: 7.831183e-06
# 157/157 [==============================] - 0s 922us/step
# Intercept 0.006766609785474224
# Prediction_local [0.001965]
# Right: 4.719174e-06
# 157/157 [==============================] - 0s 905us/step
# Intercept 0.008320020953926264
# Prediction_local [-0.0100652]
# Right: 8.074193e-06
# 157/157 [==============================] - 0s 877us/step
# Intercept -0.0012366934123898407
# Prediction_local [0.02346904]
# Right: 7.587907e-06
# 157/157 [==============================] - 0s 875us/step
# Intercept 0.00939635196706948
# Prediction_local [-0.00424521]
# Right: 4.0426679e-07
# 157/157 [==============================] - 0s 999us/step
# Intercept 0.0063653824951497556
# Prediction_local [0.00324874]
# Right: 2.455494e-07
# 157/157 [==============================] - 0s 991us/step
# Intercept 0.0076809099816904924
# Prediction_local [0.00337835]
# Right: 3.226942e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0056942211411962354
# Prediction_local [-0.00026557]
# Right: 2.5884974e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.003404814882696434
# Prediction_local [0.00688626]
# Right: 2.2120204e-05
# 157/157 [==============================] - 0s 957us/step
# Intercept 0.005241268726990534
# Prediction_local [0.00215789]
# Right: 1.4351623e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0022208198321749207
# Prediction_local [0.01271662]
# Right: 8.867175e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00615898518276963
# Prediction_local [0.00242687]
# Right: 7.5336566e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0019775193592817385
# Prediction_local [0.00963681]
# Right: 1.6250592e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0032205265228801043
# Prediction_local [0.01455214]
# Right: 7.625608e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0005421449084908343
# Prediction_local [0.02392813]
# Right: 4.3827325e-07
# 157/157 [==============================] - 0s 960us/step
# Intercept 0.0027437355783650266
# Prediction_local [0.01361095]
# Right: 9.886682e-06
# 157/157 [==============================] - 0s 912us/step
# Intercept -0.0006871399088632523
# Prediction_local [0.01614231]
# Right: 3.0169744e-05
# 157/157 [==============================] - 0s 985us/step
# Intercept 0.0021941061843600324
# Prediction_local [0.0075652]
# Right: 7.5251614e-06
# 157/157 [==============================] - 0s 842us/step
# Intercept -0.0013336691757930685
# Prediction_local [0.02061658]
# Right: 0.999997
# 157/157 [==============================] - 0s 930us/step
# Intercept 0.0033124775740001225
# Prediction_local [0.00938885]
# Right: 5.550395e-06
# 157/157 [==============================] - 0s 970us/step
# Intercept 0.004851451286326026
# Prediction_local [0.00297832]
# Right: 3.3690646e-06
# 157/157 [==============================] - 0s 975us/step
# Intercept -0.001959823643362864
# Prediction_local [0.02774236]
# Right: 1.5270681e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0007738749743731021
# Prediction_local [0.02156948]
# Right: 7.671796e-06
# 157/157 [==============================] - 0s 886us/step
# Intercept 0.005539226372081372
# Prediction_local [0.00329984]
# Right: 1.3467875e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005740379654001312
# Prediction_local [0.00063597]
# Right: 5.824478e-06
# 157/157 [==============================] - 0s 977us/step
# Intercept -0.0005211174092954497
# Prediction_local [0.01807268]
# Right: 0.99999595
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0012574088171585325
# Prediction_local [0.02197701]
# Right: 2.9391038e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005363899036976526
# Prediction_local [0.00563043]
# Right: 0.00027663304
# 157/157 [==============================] - 0s 987us/step
# Intercept -0.00040623553258388716
# Prediction_local [0.01799936]
# Right: 0.99999607
# 157/157 [==============================] - 0s 993us/step
# Intercept 0.0028458475434044945
# Prediction_local [0.00615477]
# Right: 5.603848e-06
# 157/157 [==============================] - 0s 937us/step
# Intercept 0.001279231229839686
# Prediction_local [0.01505017]
# Right: 3.6082545e-06
# 157/157 [==============================] - 0s 943us/step
# Intercept -0.0034794095566502503
# Prediction_local [0.03055317]
# Right: 0.9999943
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001264149842893008
# Prediction_local [0.01298766]
# Right: 8.502829e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.0028251300456529635
# Prediction_local [0.01570069]
# Right: 5.7141096e-05
# 157/157 [==============================] - 0s 926us/step
# Intercept 0.0019639091395897133
# Prediction_local [0.01222478]
# Right: 9.5492705e-06
# 157/157 [==============================] - 0s 948us/step
# Intercept -0.0006705761432509614
# Prediction_local [0.02082058]
# Right: 0.999996
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.0030038961008303153
# Prediction_local [0.00800295]
# Right: 3.1238294e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004508927709420772
# Prediction_local [0.00518122]
# Right: 7.5847597e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0048587472236768705
# Prediction_local [0.0122627]
# Right: 1.3695964e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.008467771307895399
# Prediction_local [-0.00553619]
# Right: 5.316249e-06
# 157/157 [==============================] - 0s 935us/step
# Intercept 0.002214029739238871
# Prediction_local [0.0131371]
# Right: 3.6252452e-06
# 157/157 [==============================] - 0s 925us/step
# Intercept 0.008001514735681874
# Prediction_local [-0.00248301]
# Right: 1.3158868e-06
# 157/157 [==============================] - 0s 965us/step
# Intercept -0.0017874959745906001
# Prediction_local [0.02677088]
# Right: 0.99999607
# 157/157 [==============================] - 0s 974us/step
# Intercept 0.007238728380661292
# Prediction_local [-0.00397626]
# Right: 2.0637845e-06
# 157/157 [==============================] - 0s 939us/step
# Intercept 0.0032500698949455295
# Prediction_local [0.00926153]
# Right: 2.2420381e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0003826162883490145
# Prediction_local [0.01610117]
# Right: 0.00018518478
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.00040515781762439675
# Prediction_local [0.01944905]
# Right: 3.495432e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0022555491080170787
# Prediction_local [0.02823663]
# Right: 0.00063372374
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0007217073765278907
# Prediction_local [0.02076402]
# Right: 0.9999963
# 157/157 [==============================] - 0s 938us/step
# Intercept 0.006346083384638923
# Prediction_local [0.00220573]
# Right: 1.7728758e-05
# 157/157 [==============================] - 0s 955us/step
# Intercept -0.0022581386278754034
# Prediction_local [0.02922953]
# Right: 7.501452e-06
# 157/157 [==============================] - 0s 981us/step
# Intercept 0.005993156286861912
# Prediction_local [0.00027911]
# Right: 7.805208e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001066990696910004
# Prediction_local [0.02093022]
# Right: 0.999996
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.00015758710993073535
# Prediction_local [0.02615285]
# Right: 0.99999607
# 157/157 [==============================] - 0s 919us/step
# Intercept -0.0010372367797678167
# Prediction_local [0.0267785]
# Right: 0.99999577
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002839500408954882
# Prediction_local [0.01177717]
# Right: 9.773483e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0037908802032016005
# Prediction_local [0.00828253]
# Right: 7.597335e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0017517261834756421
# Prediction_local [0.02439519]
# Right: 0.9999954
# 157/157 [==============================] - 0s 942us/step
# Intercept -0.0008219899631307179
# Prediction_local [0.02237518]
# Right: 2.4129014e-05
# 157/157 [==============================] - 0s 980us/step
# Intercept -0.0018330025695294907
# Prediction_local [0.02098631]
# Right: 0.9999967
# 157/157 [==============================] - 0s 876us/step
# Intercept 0.004807946111139557
# Prediction_local [0.00245078]
# Right: 6.786016e-07
# 157/157 [==============================] - 0s 930us/step
# Intercept -0.0019035111494702453
# Prediction_local [0.02487056]
# Right: 6.1626597e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001912010083086497
# Prediction_local [0.008579]
# Right: 1.0418947e-05
# 157/157 [==============================] - 0s 939us/step
# Intercept 0.0031854871658104945
# Prediction_local [0.00801779]
# Right: 6.616095e-05
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.0011875176851943
# Prediction_local [0.01484105]
# Right: 8.3100465e-05
# 157/157 [==============================] - 0s 977us/step
# Intercept -0.0001922095676149451
# Prediction_local [0.02360738]
# Right: 0.9999953
# 157/157 [==============================] - 0s 903us/step
# Intercept 0.00018489677289270333
# Prediction_local [0.0181825]
# Right: 2.4015794e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0006024875773752948
# Prediction_local [0.01814537]
# Right: 1.0707348e-05
# 157/157 [==============================] - 0s 986us/step
# Intercept 0.008688525743334697
# Prediction_local [-0.00075942]
# Right: 9.246924e-06
# 157/157 [==============================] - 0s 933us/step
# Intercept 0.0047373434465568095
# Prediction_local [0.00314566]
# Right: 1.9741561e-05
# 157/157 [==============================] - 0s 951us/step
# Intercept -0.0006887544769441948
# Prediction_local [0.02227857]
# Right: 7.498662e-06
# 157/157 [==============================] - 0s 952us/step
# Intercept -0.00066746062577958
# Prediction_local [0.01761423]
# Right: 4.7778717e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0010989393678861974
# Prediction_local [0.01995022]
# Right: 0.99999607
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002832759249898408
# Prediction_local [0.01459544]
# Right: 1.3264225e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0014591117773944682
# Prediction_local [0.02351617]
# Right: 0.99999666
# 157/157 [==============================] - 0s 956us/step
# Intercept 0.001627411757228287
# Prediction_local [0.01360187]
# Right: 1.0809279e-05
# 157/157 [==============================] - 0s 900us/step
# Intercept 0.002706756725657405
# Prediction_local [0.01164501]
# Right: 1.576055e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00273918443130088
# Prediction_local [0.00834366]
# Right: 7.961783e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.003104803155374197
# Prediction_local [0.01370831]
# Right: 0.00012944048
# 157/157 [==============================] - 0s 981us/step
# Intercept 0.004688520370333511
# Prediction_local [0.0028589]
# Right: 4.245112e-05
# 157/157 [==============================] - 0s 945us/step
# Intercept 0.005023638479536111
# Prediction_local [0.00420065]
# Right: 9.692978e-07
# 157/157 [==============================] - 0s 991us/step
# Intercept -0.001545615075777084
# Prediction_local [0.01874942]
# Right: 5.4341268e-05
# 157/157 [==============================] - 0s 990us/step
# Intercept -0.005000864472117973
# Prediction_local [0.03249402]
# Right: 1.0559252e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004566223295341878
# Prediction_local [0.00141087]
# Right: 1.8710093e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.003422252156549147
# Prediction_local [0.00761217]
# Right: 0.0002443234
# 157/157 [==============================] - 0s 987us/step
# Intercept -0.0017657446783175546
# Prediction_local [0.02514543]
# Right: 0.002179763
# 157/157 [==============================] - 0s 972us/step
# Intercept -0.0025621373926863313
# Prediction_local [0.03524291]
# Right: 0.9999967
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0020792939056834625
# Prediction_local [0.0088876]
# Right: 1.0056308e-05
# 157/157 [==============================] - 0s 930us/step
# Intercept -0.00019000129939599365
# Prediction_local [0.02086205]
# Right: 0.00035192224
# 157/157 [==============================] - 0s 980us/step
# Intercept 0.005935300891381616
# Prediction_local [0.00072865]
# Right: 1.91502e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005806136583631546
# Prediction_local [0.00231671]
# Right: 2.3831378e-06
# 157/157 [==============================] - 0s 896us/step
# Intercept -0.0015621724393920632
# Prediction_local [0.02528761]
# Right: 0.00022815162
# 157/157 [==============================] - 0s 921us/step
# Intercept 0.002095025344143799
# Prediction_local [0.01170642]
# Right: 2.4883016e-06
# 157/157 [==============================] - 0s 967us/step
# Intercept 0.006297345508769057
# Prediction_local [0.00167175]
# Right: 2.9234772e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0009311668417734276
# Prediction_local [0.02610002]
# Right: 0.99999666
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002925940697245292
# Prediction_local [0.00959157]
# Right: 5.4174798e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0025061086277969363
# Prediction_local [0.01254889]
# Right: 7.172139e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002221295823171156
# Prediction_local [0.01073838]
# Right: 2.6629918e-06
# 157/157 [==============================] - 0s 955us/step
# Intercept 0.004088812293131287
# Prediction_local [0.00353052]
# Right: 6.8595027e-06
# 157/157 [==============================] - 0s 992us/step
# Intercept 0.000421870168012475
# Prediction_local [0.02066738]
# Right: 2.8853652e-05
# 157/157 [==============================] - 0s 961us/step
# Intercept -0.001143848793669724
# Prediction_local [0.02254375]
# Right: 0.99999684
# 157/157 [==============================] - 0s 914us/step
# Intercept 0.0070996246012657496
# Prediction_local [-0.00418134]
# Right: 1.4287439e-06
# 157/157 [==============================] - 0s 916us/step
# Intercept 0.000744519991034275
# Prediction_local [0.01413274]
# Right: 3.5319374e-06
# 157/157 [==============================] - 0s 904us/step
# Intercept 0.009978195115006548
# Prediction_local [-0.01167761]
# Right: 6.529201e-06
# 157/157 [==============================] - 0s 977us/step
# Intercept -0.004311005017886319
# Prediction_local [0.02865363]
# Right: 3.873425e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0005142080743048639
# Prediction_local [0.0144184]
# Right: 2.7173382e-06
# 157/157 [==============================] - 0s 952us/step
# Intercept 0.0011231878139497985
# Prediction_local [0.01693644]
# Right: 4.810246e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00016271773009284615
# Prediction_local [0.01964261]
# Right: 0.99999666
# 157/157 [==============================] - 0s 912us/step
# Intercept 0.002551859186810259
# Prediction_local [0.00890311]
# Right: 2.2868091e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0008906970170521533
# Prediction_local [0.02312929]
# Right: 0.99999636
# 157/157 [==============================] - 0s 973us/step
# Intercept 7.000898755852355e-05
# Prediction_local [0.01997594]
# Right: 0.9999957
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001771636690861677
# Prediction_local [0.01772571]
# Right: 1.7768669e-05
# 157/157 [==============================] - 0s 951us/step
# Intercept -0.000380883899000305
# Prediction_local [0.02065104]
# Right: 0.99999595
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.0007618782002134219
# Prediction_local [0.0216339]
# Right: 0.99999607
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0040879203538047425
# Prediction_local [0.00327752]
# Right: 3.2602727e-06
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.00026300095719828526
# Prediction_local [0.0215415]
# Right: 3.9505645e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0038106297508850844
# Prediction_local [0.00975967]
# Right: 3.2510018e-06
# 157/157 [==============================] - 0s 876us/step
# Intercept -0.0010523094220962169
# Prediction_local [0.02493094]
# Right: 0.9999959
# 157/157 [==============================] - 0s 929us/step
# Intercept 0.008698999342271826
# Prediction_local [-0.00514257]
# Right: 4.321565e-06
# 157/157 [==============================] - 0s 982us/step
# Intercept 7.606832505816733e-05
# Prediction_local [0.02327745]
# Right: 0.99999547
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0016201970437662917
# Prediction_local [0.01009891]
# Right: 2.4128993e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001364953529702534
# Prediction_local [0.01547921]
# Right: 4.572694e-06
# 157/157 [==============================] - 0s 1000us/step
# Intercept 0.003907110641341285
# Prediction_local [0.00252085]
# Right: 2.0686714e-06
# 157/157 [==============================] - 0s 942us/step
# Intercept 0.0014462578113033139
# Prediction_local [0.01723839]
# Right: 3.6498716e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0010569551001383118
# Prediction_local [0.0183467]
# Right: 5.0695697e-05
# 157/157 [==============================] - 0s 961us/step
# Intercept 0.0042713589198625545
# Prediction_local [0.00439347]
# Right: 7.762783e-06
# 157/157 [==============================] - 0s 925us/step
# Intercept -0.0008507783879914453
# Prediction_local [0.02319368]
# Right: 0.9999964
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0008840178501734134
# Prediction_local [0.02510994]
# Right: 0.99999666
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002749638684005221
# Prediction_local [0.01089079]
# Right: 1.3368792e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00022263939507431024
# Prediction_local [0.01948984]
# Right: 0.99999595
# 157/157 [==============================] - 0s 2ms/step
# Intercept -0.0025563832349105673
# Prediction_local [0.02745987]
# Right: 0.99999726
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002014959608588016
# Prediction_local [0.01116774]
# Right: 5.777053e-06
# 157/157 [==============================] - 0s 996us/step
# Intercept 0.005661924125976749
# Prediction_local [0.00257604]
# Right: 2.145014e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001503316793183016
# Prediction_local [0.02520131]
# Right: 2.7914093e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0047573502433818455
# Prediction_local [0.00316555]
# Right: 1.565225e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0008587055326703119
# Prediction_local [0.02182009]
# Right: 1.3534815e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.009811990857294851
# Prediction_local [-0.00668139]
# Right: 5.5726073e-06
# 157/157 [==============================] - 0s 1000us/step
# Intercept 0.0024195103322066517
# Prediction_local [0.01389973]
# Right: 6.10312e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0026640373731221054
# Prediction_local [0.02509426]
# Right: 0.99999636
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004786957200349472
# Prediction_local [0.00241676]
# Right: 3.3322697e-06
# 157/157 [==============================] - 0s 938us/step
# Intercept 3.207283070628519e-05
# Prediction_local [0.02096974]
# Right: 0.99999624
# 157/157 [==============================] - 0s 935us/step
# Intercept -0.0014890258085293504
# Prediction_local [0.01875767]
# Right: 0.99999577
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0003856404916973708
# Prediction_local [0.02236824]
# Right: 0.99999684
# 157/157 [==============================] - 0s 940us/step
# Intercept -0.0024564939673684906
# Prediction_local [0.02573067]
# Right: 0.99999565
# 157/157 [==============================] - 0s 934us/step
# Intercept 0.0053865899855116885
# Prediction_local [0.00235045]
# Right: 2.6324392e-06
# 157/157 [==============================] - 0s 919us/step
# Intercept 0.00541065855341662
# Prediction_local [0.000755]
# Right: 6.7260276e-06
# 157/157 [==============================] - 0s 916us/step
# Intercept 0.005855613883680352
# Prediction_local [0.0023868]
# Right: 1.7070572e-06
# 157/157 [==============================] - 0s 932us/step
# Intercept -0.003232073331187987
# Prediction_local [0.02759239]
# Right: 0.9999957
# 157/157 [==============================] - 0s 881us/step
# Intercept 0.00017818327890637472
# Prediction_local [0.01915207]
# Right: 2.8655032e-07
# 157/157 [==============================] - 0s 919us/step
# Intercept 0.0009159651555774272
# Prediction_local [0.01365949]
# Right: 3.198175e-05
# 157/157 [==============================] - 0s 910us/step
# Intercept 0.0005682520503021036
# Prediction_local [0.01741255]
# Right: 1.5858398e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.001975708508283912
# Prediction_local [0.02817004]
# Right: 0.9999967
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.004796221791339585
# Prediction_local [0.00143318]
# Right: 3.3846643e-06
# 157/157 [==============================] - 0s 945us/step
# Intercept 0.0017345327173247972
# Prediction_local [0.0103812]
# Right: 2.6573864e-05
# 157/157 [==============================] - 0s 943us/step
# Intercept 0.0044660714227121
# Prediction_local [0.00692776]
# Right: 6.627841e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00021809168216167015
# Prediction_local [0.02382648]
# Right: 0.0007105938
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0024961990538428674
# Prediction_local [0.01324251]
# Right: 3.6816493e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0004916567713020414
# Prediction_local [0.01904365]
# Right: 0.99999195
# 157/157 [==============================] - 0s 925us/step
# Intercept 0.003846459178521191
# Prediction_local [0.00097864]
# Right: 1.1015819e-05
# 157/157 [==============================] - 0s 972us/step
# Intercept -0.0009141720559511105
# Prediction_local [0.0178994]
# Right: 0.009396331
# 157/157 [==============================] - 0s 962us/step
# Intercept 0.0028877860704276644
# Prediction_local [0.00765435]
# Right: 2.2555462e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0035474738241661045
# Prediction_local [0.00466618]
# Right: 4.9699574e-06
# 157/157 [==============================] - 0s 968us/step
# Intercept 0.0058071960359363335
# Prediction_local [0.00038352]
# Right: 0.00046155282
# 157/157 [==============================] - 0s 928us/step
# Intercept -0.0018044554778206207
# Prediction_local [0.02383797]
# Right: 0.99999636
# 157/157 [==============================] - 0s 952us/step
# Intercept -0.003012282508910573
# Prediction_local [0.02353246]
# Right: 0.999992
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.006463785860695273
# Prediction_local [0.00157864]
# Right: 5.3718104e-06
# 157/157 [==============================] - 0s 932us/step
# Intercept 0.003438168861576224
# Prediction_local [0.00758582]
# Right: 0.00014284016
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0008994409004655143
# Prediction_local [0.02638815]
# Right: 0.9999964
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005542932860234615
# Prediction_local [0.00280228]
# Right: 3.2388214e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0033758457221230997
# Prediction_local [0.01045567]
# Right: 7.932347e-06
# 157/157 [==============================] - 0s 996us/step
# Intercept -0.0012823133211674626
# Prediction_local [0.0180803]
# Right: 0.99999696
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0012537506953860388
# Prediction_local [0.00929965]
# Right: 1.2949534e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.007067268731338564
# Prediction_local [0.0003606]
# Right: 3.9062645e-05
# 157/157 [==============================] - 0s 929us/step
# Intercept -0.0019388482373713543
# Prediction_local [0.02647603]
# Right: 4.447424e-06
# 157/157 [==============================] - 0s 961us/step
# Intercept -0.003445173307382303
# Prediction_local [0.03041921]
# Right: 0.99999547
# 157/157 [==============================] - 0s 911us/step
# Intercept 0.005176905317641143
# Prediction_local [7.19136027e-05]
# Right: 7.564401e-07
# 157/157 [==============================] - 0s 994us/step
# ...
# Right: 0.9999947
# 157/157 [==============================] - 0s 930us/step
# Intercept -0.0001009632924334012
# Prediction_local [0.01957046]
# Right: 0.9999964
# 157/157 [==============================] - 0s 943us/step
# Intercept -0.005285140965545253
# Prediction_local [0.03515819]
# Right: 4.252505e-06
# 157/157 [==============================] - 0s 927us/step
# Intercept 0.0032893213078165695
# Prediction_local [0.00610494]
# Right: 7.333746e-05
# 157/157 [==============================] - 0s 866us/step
# Intercept -0.0011212913429803012
# Prediction_local [0.01821686]
# Right: 2.4640125e-05
# 157/157 [==============================] - 0s 936us/step
# Intercept 0.003515660166918567
# Prediction_local [0.01010086]
# Right: 2.515866e-06
# 157/157 [==============================] - 0s 932us/step
# Intercept 0.003150954231095945
# Prediction_local [0.00849075]
# Right: 1.9992618e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005654314537419787
# Prediction_local [0.00180608]
# Right: 1.9419183e-05
# 157/157 [==============================] - 0s 943us/step
# Intercept 0.006304827506779829
# Prediction_local [0.00047997]
# Right: 0.00043443913
# 157/157 [==============================] - 0s 887us/step
# Intercept 0.0005777950018142752
# Prediction_local [0.01835439]
# Right: 0.9999942
# 157/157 [==============================] - 0s 958us/step
# Intercept 0.0026105970778434137
# Prediction_local [0.01104815]
# Right: 7.0777523e-06
# 157/157 [==============================] - 0s 977us/step
# Intercept -0.0004916527065781575
# Prediction_local [0.02138954]
# Right: 0.9999957
# 157/157 [==============================] - 0s 981us/step
# Intercept -0.00017040138603184075
# Prediction_local [0.01756682]
# Right: 1.3662501e-05
# 157/157 [==============================] - 0s 968us/step
# Intercept -4.670975952498265e-05
# Prediction_local [0.01778809]
# Right: 5.5345276e-06
# 157/157 [==============================] - 0s 989us/step
# Intercept -0.0008524498386494207
# Prediction_local [0.02123106]
# Right: 1.5308445e-06
# 157/157 [==============================] - 0s 946us/step
# Intercept 0.002448611796697295
# Prediction_local [0.01131639]
# Right: 9.1947265e-07
# 157/157 [==============================] - 0s 955us/step
# Intercept -0.0008017765911668018
# Prediction_local [0.02123082]
# Right: 0.9999955
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002159704144528219
# Prediction_local [0.01156575]
# Right: 4.3688724e-05
# 157/157 [==============================] - 0s 950us/step
# Intercept 0.0014611933556704301
# Prediction_local [0.01487171]
# Right: 3.1386196e-05
# 157/157 [==============================] - 0s 930us/step
# Intercept 0.0018109992512362243
# Prediction_local [0.01061648]
# Right: 2.5574609e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.003252025283355826
# Prediction_local [0.0267345]
# Right: 4.8993603e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0018614063350680839
# Prediction_local [0.02389531]
# Right: 0.9999964
# 157/157 [==============================] - 0s 949us/step
# Intercept 0.0042100530490177205
# Prediction_local [0.00484202]
# Right: 3.287835e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0020611599356868023
# Prediction_local [0.02581943]
# Right: 0.9999966
# 157/157 [==============================] - 0s 964us/step
# Intercept 0.003125082987315715
# Prediction_local [0.00804275]
# Right: 2.4285425e-06
# 157/157 [==============================] - 0s 949us/step
# Intercept -0.0015946335077824912
# Prediction_local [0.02072665]
# Right: 0.99999595
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.009680528987238831
# Prediction_local [-0.00526235]
# Right: 0.00022827413
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0006331290905052271
# Prediction_local [0.02095786]
# Right: 0.99999684
# 157/157 [==============================] - 0s 896us/step
# Intercept 0.00122863476425301
# Prediction_local [0.01392304]
# Right: 7.542422e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0002191976490558238
# Prediction_local [0.02470715]
# Right: 0.9999961
# 157/157 [==============================] - 0s 890us/step
# Intercept -0.0006256344348983204
# Prediction_local [0.01989385]
# Right: 0.99999547
# 157/157 [==============================] - 0s 902us/step
# Intercept 0.0001354389513304622
# Prediction_local [0.02448031]
# Right: 0.99999684
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0043402274344937495
# Prediction_local [0.00074107]
# Right: 7.828929e-06
# 157/157 [==============================] - 0s 963us/step
# Intercept -0.002054654677889755
# Prediction_local [0.02412649]
# Right: 0.99999684
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.004168743950325201
# Prediction_local [0.00859245]
# Right: 4.8432816e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -2.5173568388049163e-05
# Prediction_local [0.01861517]
# Right: 1.1700511e-05
# 157/157 [==============================] - 0s 980us/step
# Intercept 0.0012677019103686667
# Prediction_local [0.01101271]
# Right: 1.4611277e-05
# 157/157 [==============================] - 0s 985us/step
# Intercept -0.002086879545172486
# Prediction_local [0.0273277]
# Right: 0.9999965
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0025678337876761546
# Prediction_local [0.01502897]
# Right: 4.0560362e-06
# 157/157 [==============================] - 0s 936us/step
# Intercept 0.00985032103483889
# Prediction_local [-0.00825064]
# Right: 1.5646652e-05
# 157/157 [==============================] - 0s 925us/step
# Intercept 0.004783229431609327
# Prediction_local [0.00484741]
# Right: 0.00017782058
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0007015830388856668
# Prediction_local [0.02053174]
# Right: 0.9999959
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0033317863569276712
# Prediction_local [0.00522008]
# Right: 5.4933016e-06
# 157/157 [==============================] - 0s 894us/step
# Intercept -0.001147113649178356
# Prediction_local [0.02354793]
# Right: 0.9999958
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0004488068773332273
# Prediction_local [0.02051632]
# Right: 0.999997
# 157/157 [==============================] - 0s 927us/step
# Intercept 0.0029833477919480053
# Prediction_local [0.01593169]
# Right: 2.6220587e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.00528128181323284
# Prediction_local [0.00438765]
# Right: 2.1923179e-06
# 157/157 [==============================] - 0s 920us/step
# Intercept 0.0026425566577741345
# Prediction_local [0.00836481]
# Right: 1.7669869e-05
# 157/157 [==============================] - 0s 874us/step
# Intercept -0.002295782193642383
# Prediction_local [0.02304654]
# Right: 0.999997
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0015607562857673156
# Prediction_local [0.01135526]
# Right: 0.0010095787
# 157/157 [==============================] - 0s 973us/step
# Intercept 0.004539219540846772
# Prediction_local [0.00501119]
# Right: 1.3305629e-06
# 157/157 [==============================] - 0s 950us/step
# Intercept -0.001623188679119287
# Prediction_local [0.02265748]
# Right: 0.0003009361
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.006941276571623939
# Prediction_local [-0.00311225]
# Right: 8.1940414e-07
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002255943207568225
# Prediction_local [0.01430967]
# Right: 3.0554584e-06
# 157/157 [==============================] - 0s 922us/step
# Intercept -0.0008231338938648764
# Prediction_local [0.02165732]
# Right: 0.99999565
# 157/157 [==============================] - 0s 905us/step
# Intercept 0.0027053881892681953
# Prediction_local [0.00837236]
# Right: 3.788474e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept -0.002164863872058019
# Prediction_local [0.02509142]
# Right: 0.9999964
# 157/157 [==============================] - 0s 926us/step
# Intercept 0.005361468633634478
# Prediction_local [0.00473755]
# Right: 3.4293957e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0019024119308195444
# Prediction_local [0.02467171]
# Right: 0.99999654
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0005488398609824127
# Prediction_local [0.02437875]
# Right: 4.4670883e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0022914232340511967
# Prediction_local [0.03003102]
# Right: 0.999996
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.007245919797275919
# Prediction_local [-0.00497471]
# Right: 3.190269e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005563270290122109
# Prediction_local [0.00161713]
# Right: 2.352298e-06
# 157/157 [==============================] - 0s 987us/step
# Intercept -0.00023211341628990873
# Prediction_local [0.02230826]
# Right: 0.99999547
# 157/157 [==============================] - 0s 948us/step
# Intercept 0.005679271344761485
# Prediction_local [0.00624732]
# Right: 1.4797741e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0012794121957734107
# Prediction_local [0.00947013]
# Right: 1.5239547e-06
# 157/157 [==============================] - 0s 953us/step
# Intercept 0.0035487176911773873
# Prediction_local [0.00821955]
# Right: 1.0589974e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.007003488186750926
# Prediction_local [-0.00362507]
# Right: 3.8103975e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.006524029915893769
# Prediction_local [0.00089425]
# Right: 5.7793286e-06
# 157/157 [==============================] - 0s 979us/step
# Intercept 0.008879112415960257
# Prediction_local [-0.00686975]
# Right: 9.8459e-05
# 157/157 [==============================] - 0s 926us/step
# Intercept 0.00602849154982063
# Prediction_local [0.00514854]
# Right: 2.1916549e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001942100248279904
# Prediction_local [0.01371353]
# Right: 7.962491e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.001515459875088102
# Prediction_local [0.01056249]
# Right: 9.114155e-06
# 157/157 [==============================] - 0s 888us/step
# Intercept -0.001039860960543708
# Prediction_local [0.0215957]
# Right: 0.9999965
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0016467345203673763
# Prediction_local [0.02343238]
# Right: 0.99999684
# 157/157 [==============================] - 0s 931us/step
# Intercept -0.003377004594204907
# Prediction_local [0.02973911]
# Right: 0.999996
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.0019368179500258904
# Prediction_local [0.00791083]
# Right: 0.0018698643
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.000830743271062963
# Prediction_local [0.01692319]
# Right: 0.0099874595
# 157/157 [==============================] - 0s 913us/step
# Intercept 0.003180776873986176
# Prediction_local [0.0076332]
# Right: 5.708534e-06
# 157/157 [==============================] - 0s 976us/step
# Intercept 0.006286849088029784
# Prediction_local [-0.00024882]
# Right: 4.316898e-06
# 157/157 [==============================] - 0s 907us/step
# Intercept -0.0011752205666680374
# Prediction_local [0.02759703]
# Right: 6.4441556e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0003013811853679613
# Prediction_local [0.02223484]
# Right: 0.9999972
# 157/157 [==============================] - 0s 992us/step
# Intercept -0.0005011324207521203
# Prediction_local [0.02210783]
# Right: 0.9999944
# 157/157 [==============================] - 0s 987us/step
# Intercept 0.003561489995317807
# Prediction_local [0.00537841]
# Right: 0.00014152886
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.006475517553212849
# Prediction_local [-0.00524756]
# Right: 7.5863513e-06
# 157/157 [==============================] - 0s 935us/step
# Intercept 0.007853980566597026
# Prediction_local [-0.00482647]
# Right: 0.00013025383
# 157/157 [==============================] - 0s 992us/step
# Intercept 0.006438521173877822
# Prediction_local [0.00027907]
# Right: 8.386211e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005898035984554297
# Prediction_local [0.00131271]
# Right: 7.4128036e-07
# 157/157 [==============================] - 0s 899us/step
# Intercept 0.0006667423174305676
# Prediction_local [0.02164395]
# Right: 1.4550614e-06
# 157/157 [==============================] - 0s 978us/step
# Intercept 0.00830113989050565
# Prediction_local [-0.00438077]
# Right: 6.8718387e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.008269816404670345
# Prediction_local [-0.00483174]
# Right: 8.703113e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0013626131902362455
# Prediction_local [0.02376765]
# Right: 0.999996
# 157/157 [==============================] - 0s 922us/step
# Intercept 0.005301473649596723
# Prediction_local [0.00197381]
# Right: 3.0352185e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005083293651614217
# Prediction_local [0.00217334]
# Right: 9.501878e-06
# 157/157 [==============================] - 0s 976us/step
# Intercept -0.00283172913331212
# Prediction_local [0.02373984]
# Right: 8.462187e-06
# 157/157 [==============================] - 0s 955us/step
# Intercept -0.0035768465646601744
# Prediction_local [0.03634922]
# Right: 0.9999962
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0036155964520440814
# Prediction_local [0.0285195]
# Right: 0.9999958
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0005333526465987164
# Prediction_local [0.0224214]
# Right: 1.127178e-05
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0055275082827459365
# Prediction_local [0.00412904]
# Right: 0.0046875165
# 157/157 [==============================] - 0s 1ms/step
# Intercept -0.0022544827035979936
# Prediction_local [0.02745319]
# Right: 0.9999968
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.005479546389058187
# Prediction_local [0.00181683]
# Right: 3.241231e-05
# 157/157 [==============================] - 0s 996us/step
# Intercept 0.002870625463748235
# Prediction_local [0.00874329]
# Right: 2.6125115e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.0058215088244086945
# Prediction_local [-0.00098875]
# Right: 4.336804e-06
# 157/157 [==============================] - 0s 983us/step
# Intercept 0.0025364112801765874
# Prediction_local [0.00929984]
# Right: 1.0248931e-06
# 157/157 [==============================] - 0s 980us/step
# Intercept 0.008151782827838613
# Prediction_local [-0.00408565]
# Right: 0.00011443438
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.002517864226095704
# Prediction_local [0.01095009]
# Right: 4.7279486e-06
# 157/157 [==============================] - 0s 892us/step
# Intercept 0.002255947864452098
# Prediction_local [0.01158863]
# Right: 0.00045258933
# 157/157 [==============================] - 0s 949us/step
# Intercept 0.011921930800300734
# Prediction_local [-0.00839439]
# Right: 6.571373e-06
# 157/157 [==============================] - 0s 918us/step
# Intercept 0.0038665536353911113
# Prediction_local [0.0094291]
# Right: 1.2130093e-06
# 157/157 [==============================] - 0s 931us/step
# Intercept 0.0012363986159693446
# Prediction_local [0.01288616]
# Right: 6.863285e-06
# 157/157 [==============================] - 0s 875us/step
# Intercept -0.0014273132591519355
# Prediction_local [0.0262266]
# Right: 1.2341281e-05
# 157/157 [==============================] - 0s 904us/step
# Intercept 0.002568111038912132
# Prediction_local [0.0072639]
# Right: 3.2635328e-06
# 157/157 [==============================] - 0s 891us/step
# Intercept 0.0020462103431380376
# Prediction_local [0.01072857]
# Right: 4.999936e-06
# 157/157 [==============================] - 0s 917us/step
# Intercept -0.0006614461623808709
# Prediction_local [0.01676868]
# Right: 8.637559e-06
# 157/157 [==============================] - 0s 920us/step
# Intercept 0.0005494670384919784
# Prediction_local [0.02200592]
# Right: 0.9999966
# 157/157 [==============================] - 0s 944us/step
# Intercept 0.003117766678243801
# Prediction_local [0.00753688]
# Right: 3.834704e-06
# 157/157 [==============================] - 0s 1ms/step
# Intercept 0.007447734162073336
# Prediction_local [0.00260183]
# Right: 4.0933096e-06

# %%
True_predictions_feature_importances = np.zeros(len(X.columns))

# %%
for exp in True_predictions_explanations:
    for feature_name, importance in exp.as_list():
        original_feature_name = feature_name.split(' ')[0]
        if original_feature_name in feature_name_to_index:
            feature_index = feature_name_to_index[original_feature_name]
            True_predictions_feature_importances[feature_index] += np.abs(importance)

# %%
True_predictions_feature_importances /= np.sum(True_predictions_feature_importances)

# %%
for feature_name, ftr_importance in zip(X.columns, True_predictions_feature_importances):
    print(f"{feature_name}:{ftr_importance}")
# Out:
# Time:0.011738436776357084
# V1:0.013649508041667995
# V2:0.04602109653849483
# V3:0.0722110077499402
# V4:0.08948683619333293
# V5:0.0023551878015175783
# V6:0.0013566829672934507
# V7:0.11620908885353741
# V8:0.017399649103165323
# V9:0.04333959071382983
# V10:0.0344193439450215
# V11:0.05063945737513297
# V12:0.17844113281774673
# V13:0.0029473176856581137
# V14:0.08969242322875627
# V15:0.0019896314428440413
# V16:0.0566248852168488
# V17:0.020453287005509455
# V18:0.0014690373653910502
# V19:0.0023479698295990723
# V20:0.0029510166672268687
# V21:0.002694311444425906
# V22:0.0016720729491973448
# V23:0.005669204660818172
# V24:0.002155078585385897
# V25:0.0045397531616341935
# V26:0.002043161763390583
# V27:0.004628110519624921
# V28:0.11945472424864563
# Amount:0.0014009953480058391
